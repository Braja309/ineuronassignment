# %% [raw]
# 1) . What is the difference between enclosing a list comprehension in square brackets and parentheses?

# %% [markdown]
# 1->
# Square brackets are lists while parentheses are tuples.
# A list is mutable, meaning contents can be changed, while tuples are not mutable.

# %% [raw]
# 2) What is the relationship between generators and iterators?

# %% [markdown]
# 2->
# Iterators are used mostly to iterate or convert other objects to an iterator using iter() function.
# Generators are mostly used in loops to generate an iterator by returning all the values in the loop without affecting the iteration of the loop.

# %% [raw]
# 3) What are the signs that a function is a generator function?

# %% [markdown]
# 3->
# If a function contains at least one yield statement (it may contain other yield or return statements), it becomes a generator function. Both yield and return will return some value from a function.

# %% [raw]
# 4) What is the purpose of a yield statement?

# %% [markdown]
# 4->Yield is used to return from a function without destroying the states of its local variable and when the function is called, the execution starts from the last yield statement.

# %% [raw]
# 5) What is the relationship between map calls and list comprehensions? Make a comparison and contrast between the two.

# %%
#5->The map function takes an Expression and an Iterable. The output will be an Iterable object where the expression will work on each element of the given Iterable. The output of each expression will be an element of the resultant Iterable. Python List Comprehension is used for creating a list where each element is generated by applying a simple formula on the given list.
def numCube (n) :  
    return n**3  
num = [0, 1, 2, 3, 4]  
print(map(numCube, num))
print(list(map(numCube, num)))
print([n**3 for n in num])
# Out:
# ...
# [0, 1, 8, 27, 64]
# [0, 1, 8, 27, 64]
