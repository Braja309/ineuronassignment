# %% [markdown]
# 1-> Read-binary ('rb') for PdfFileReader() and write-binary ('wb') for PdfFileWriter()

# %%
#2-> getPage(4)
import PyPDF2
pdf= open('C:\\Users\\Braja\\Desktop\\Data Science\\Linkedin Docs\\26 Pages of Python Basics_1559026634.pdf','rb')
pdfreader = PyPDF2.PdfFileReader(pdf)
pdfreader.getPage(4)
# Out:
# {'/Type': '/Page',
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 26,
#   '/Kids': [IndirectObject(3, 0),
#    IndirectObject(42, 0),
#    IndirectObject(66, 0),
#    IndirectObject(104, 0),
#    IndirectObject(137, 0),
#    IndirectObject(181, 0),
#    IndirectObject(211, 0),
#    IndirectObject(247, 0),
#    IndirectObject(275, 0),
#    IndirectObject(305, 0),
#    IndirectObject(321, 0),
#    IndirectObject(361, 0),
#    IndirectObject(386, 0),
#    IndirectObject(428, 0),
#    IndirectObject(445, 0),
#    IndirectObject(467, 0),
#    IndirectObject(484, 0),
#    IndirectObject(517, 0),
#    IndirectObject(544, 0),
#    IndirectObject(586, 0),
#    IndirectObject(604, 0),
#    IndirectObject(632, 0),
#    IndirectObject(644, 0),
#    IndirectObject(671, 0),
#    IndirectObject(696, 0),
#    IndirectObject(718, 0)]},
#  '/Resources': {'/Font': {'/F1': {'/Type': '/Font',
#     '/Subtype': '/TrueType',
#     '/Name': '/F1',
#     '/BaseFont': '/ABCDEE+Calibri',
# ...

# %%
#3->
pdfreader.numPages
# Out:
# 26

# %% [markdown]
# 4-> decrypt('swordfish')

# %%
#5-> 
pdfreader.getPage(0).rotateClockwise(90)
#pdfreader.getPage(0).rotateCounterClockwise(90)
# Out:
# {'/Type': '/Page',
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 26,
#   '/Kids': [IndirectObject(3, 0),
#    IndirectObject(42, 0),
#    IndirectObject(66, 0),
#    IndirectObject(104, 0),
#    IndirectObject(137, 0),
#    IndirectObject(181, 0),
#    IndirectObject(211, 0),
#    IndirectObject(247, 0),
#    IndirectObject(275, 0),
#    IndirectObject(305, 0),
#    IndirectObject(321, 0),
#    IndirectObject(361, 0),
#    IndirectObject(386, 0),
#    IndirectObject(428, 0),
#    IndirectObject(445, 0),
#    IndirectObject(467, 0),
#    IndirectObject(484, 0),
#    IndirectObject(517, 0),
#    IndirectObject(544, 0),
#    IndirectObject(586, 0),
#    IndirectObject(604, 0),
#    IndirectObject(632, 0),
#    IndirectObject(644, 0),
#    IndirectObject(671, 0),
#    IndirectObject(696, 0),
#    IndirectObject(718, 0)]},
#  '/Resources': {'/Font': {'/F1': {'/Type': '/Font',
#     '/Subtype': '/TrueType',
#     '/Name': '/F1',
#     '/BaseFont': '/ABCDEE+Calibri',
# ...

# %% [markdown]
# 6-> A document contains multiple paragraphs. A paragraph begins on a new line and contains multiple runs. Runs are contiguous groups of characters within a paragraph.

# %% [markdown]
# 7-> doc.paragraphs

# %% [markdown]
# 8-> Run object

# %% [markdown]
# 9->
#
#     True always makes the Run object bolded
#     False makes it always not bolded, no matter what the style’s bold setting is.
#     None will make the Run object just use the style’s bold setting.

# %% [markdown]
# 10-> docs.Document()

# %% [markdown]
# 11-> doc.add_paragraph('Hello there!')

# %% [markdown]
# 12-> 0, 1, 2, 3, and 4
